# %%
# Jupyter Notebook for Simple Interest Calculation

# Example function to calculate simple interest
def calculate_simple_interest(principal, rate, time):
    return (principal * rate * time) / 100

# Example usage
principal = 1000  # Principal amount
rate = 5  # Annual interest rate in percentage
time = 3  # Time period in years

interest = calculate_simple_interest(principal, rate, time)
print(f"The simple interest is: {interest}")

# Experiment with different values and test cases here

# %%
# Define the Square class
class SimpleInterest:
    def __init__(self, principal, time, rate):
        """
        Constructor method (__init__):
        This method is called automatically when a new Square object is created.
        It initializes the attributes of the Square object.
        
        Parameters:
        - principal: The principal amount.
        """
        self.principal = principal  # Set the side attribute to the value passed as an argument
        self.time = time  # Set the side attribute to the value passed as an argument
        self.rate = rate  # Set the side attribute to the value passed as an argument


    def set_principal(self, principal):
        """
        Method to set the side principal.
        
        Parameters:
        - principal: The new value for the side interest calculation.
        """
        self.principal = principal  # Set the side attribute to the new value

    def get_principal(self):
        """
        Method to get the side length of the square.
        
        Returns:
        - The current side length of the square.
        """
        return self.principal  # Return the value of the side attribute

    # Example function to calculate simple interest
    def calculate_simple_interest(principal, rate, time):
        """
        Method to calculate the simple interest.
        
        Returns:
        
        - The simple interest of the time principal, time and rate
        
        """
        return (principal * rate * time) / 100 #calculate simple interest

interest = calculate_simple_interest(principal, rate, time)
print(f"The simple interest is: {interest}")    
    
    
    def display_simple_interest(self):
        """
        Method to display the area of the square.
        It prints the side length and the calculated area.
        """
        principal = self.get_principal()  # Get the side length of the square
        time = self.get_time()  # Calculate the area of the square
        rate = self.rate()
        print(f"Side length of the square is: {side}")  # Print the side length
        print(f"Area of the square is: {area}")  # Print the calculated area

# Create an instance of the Square class with a specific side length
square = Square(4)

# Display the area of the square
square.display_area()

# Change the side length of the square
square.set_side(7)

# Display the updated area of the square
square.display_area()
