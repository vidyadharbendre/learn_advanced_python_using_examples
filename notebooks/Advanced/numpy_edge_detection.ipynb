# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="12%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Numpy Edge Detection </b>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/vidyadharbendre/learn_advanced_python_using_examples/blob/main/notebooks/Advanced/numpy_edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/vidyadharbendre/learn_advanced_python_using_examples/blob/main/notebooks/Advanced/numpy_edge_detection.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %%
# Importing the numpy library for numerical operations
import numpy as np

# Importing the pyplot module from matplotlib for plotting
import matplotlib.pyplot as plt

# This magic command is used to display matplotlib plots inline in Jupyter notebooks
# %matplotlib inline

# %%
# !ls
# Out:
# 1600px-Sunflower_from_Silesia2.jpg  advanced_python_programming_2.ipynb
# Learn_OOPs.ipynb                    df_store.csv
# advanced_python_programming_1.ipynb numpy_edge_detection.ipynb

# %%
# Read in the image file named '1600px-Sunflower_from_Silesia2.jpg'
# plt.imread reads the image and stores it as a numpy array
img = plt.imread('1600px-Sunflower_from_Silesia2.jpg')
plt.imshow(img)
plt.show()

# %%
# Define the vertical filter (Sobel filter) used for detecting vertical edges in the image
vertical_filter = [[-1, -2, -1],   # The vertical filter emphasizes vertical changes
                   [ 0,  0,  0],   # The middle row has no effect
                   [ 1,  2,  1]]   # The bottom row emphasizes vertical changes in the opposite direction

# Define the horizontal filter (Sobel filter) used for detecting horizontal edges in the image
horizontal_filter = [[-1, 0, 1],   # The horizontal filter emphasizes horizontal changes
                     [-2, 0, 2],   # The middle column has no effect
                     [-1, 0, 1]]   # The right column emphasizes horizontal changes in the opposite direction

# Read in the image file named '1600px-Sunflower_from_Silesia2.jpg'
# plt.imread reads the image and stores it as a numpy array
img = plt.imread('1600px-Sunflower_from_Silesia2.jpg')

# Get the dimensions of the image
# n: height of the image
# m: width of the image
# d: depth (number of color channels, typically 3 for RGB)
n, m, d = img.shape

# Initialize the edges image by making a copy of the original image
# This will be used to store the results of the edge detection process
edges_img = img.copy()
