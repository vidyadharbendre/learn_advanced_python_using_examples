# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="12%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Advanced Python Programming<br> (Day 3) </b>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/vidyadharbendre/learn_advanced_python_using_examples/blob/main/notebooks/Advanced/advanced_python_programming_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/vidyadharbendre/learn_advanced_python_using_examples/blob/main/notebooks/Advanced/advanced_python_programming_3.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
#  <td>
#     <a target="_blank" href="https://github.com/vidyadharbendre/learn_advanced_python_using_examples/blob/main/notebooks/Advanced/advanced_python_programming_3.ipynb">
#       <img src="https://img.shields.io/badge/Open%20in-GitHub-100000?style=flat&logo=github&logoColor=white" alt="Open in GitHub"/>
#     </a>
#   </td>
# </table>

# %%
# Load and display image
img = plt.imread("../images/relationship.png")
plt.imshow(img)
plt.axis("off")  # Hide axes
plt.show()

# %% [markdown]
# - Matplotlib

# %% [raw]
# - Matplotlib is the base or core visualization library in Python.
#
# - It provides the foundation for plotting, and both Pandas and Seaborn rely on it for rendering charts.

# %% [markdown]
# - Numpy

# %% [raw]
# - Numpy is the foundation of numerical computing and provides data structures (arrays) that Pandas uses. Numpy supports numerical operations, which Pandas and Matplotlib use. Numpy provides numerical data that both Pandas and Matplotlib process.
#
# - Matplotlib can also work directly with Numpy arrays for plotting.

# %% [markdown]
# - Pandas

# %% [raw]
# - Pandas integrates Matplotlib for basic plotting.Pandas relies on Matplotlib for plotting DataFrames. Pandas uses Matplotlib to generate plots from DataFrames directly.
#
# - When you call .plot() on a Pandas DataFrame, it internally uses Matplotlib to create the visualizations.

# %% [markdown]
# - Seaborn

# %% [raw]
# - Seaborn is built on top of Matplotlib and extends its capabilities. Seaborn uses Matplotlib to create aesthetically pleasing statistical plots.
#
# - It provides higher-level functions for statistical plotting and works well with Pandas DataFrames.
#
# - When you create a Seaborn plot, it internally calls Matplotlib functions.

# %%
import pandas as pd
import numpy as np

# %%
# Step 1: Create a sample dataset (wide format)
data = {
    "ID": [1, 2, 3, 4],
    "Math": [85, 78, 92, 88],
    "Science": [90, 82, 95, 85],
    "English": [88, 80, 85, 89]
}

df_wide = pd.DataFrame(data)
#print("Original (Wide Format) DataFrame:\n", df_wide)
df_wide
# Out:
#    ID  Math  Science  English
# 0   1    85       90       88
# 1   2    78       82       80
# 2   3    92       95       85
# 3   4    88       85       89

# %%
# Step 2: Melt the DataFrame
df_melted = pd.melt(df_wide, id_vars=["ID"], var_name="Subject", value_name="Marks")

# print("\nMelted (Long Format) DataFrame:\n", df_melted)
df_melted
# Out:
#     ID  Subject  Marks
# 0    1     Math     85
# 1    2     Math     78
# 2    3     Math     92
# 3    4     Math     88
# 4    1  Science     90
# 5    2  Science     82
# 6    3  Science     95
# 7    4  Science     85
# 8    1  English     88
# 9    2  English     80
# 10   3  English     85
# 11   4  English     89

# %%
#scenario 2

# Sample sales data
sales_data = {
    "Store": ["A", "B"],
    "Q1": [100, 120],
    "Q2": [150, 170],
    "Q3": [200, 220],
    "Q4": [250, 270]
}

df_sales = pd.DataFrame(sales_data)
df_sales
# Out:
#   Store   Q1   Q2   Q3   Q4
# 0     A  100  150  200  250
# 1     B  120  170  220  270

# %%
pd.melt(frame=df_sales, id_vars=['Store'], value_name='Sales')
# Out:
#   Store variable  Sales
# 0     A       Q1    100
# 1     B       Q1    120
# 2     A       Q2    150
# 3     B       Q2    170
# 4     A       Q3    200
# 5     B       Q3    220
# 6     A       Q4    250
# 7     B       Q4    270

# %%
# Melt the DataFrame
df_melted = pd.melt(df_sales, id_vars=["Store"], var_name="Quarter", value_name="Sales")

df_melted
# Out:
#   Store Quarter  Sales
# 0     A      Q1    100
# 1     B      Q1    120
# 2     A      Q2    150
# 3     B      Q2    170
# 4     A      Q3    200
# 5     B      Q3    220
# 6     A      Q4    250
# 7     B      Q4    270

# %%
# Creating a DataFrame with Indian names and their scores in various subjects
df = pd.DataFrame({
    'Name': ['Aarav', 'Ananya', 'Rohan', 'Diya'],
    'Math': [85, 92, 78, 89],
    'Science': [88, 95, 80, 90],
    'English': [90, 94, 79, 88]
})

print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#      Name  Math  Science  English
# 0   Aarav    85       88       90
# 1  Ananya    92       95       94
# 2   Rohan    78       80       79
# 3    Diya    89       90       88

# %%
print('melt' in dir(df))
# Out:
# True

# %%
# Melting the DataFrame to long format
melted_df = df.melt(id_vars=['Name'], var_name='Subject', value_name='Score')

print("\nMelted DataFrame:")
melted_df
# Out:
# Melted DataFrame:
#       Name  Subject  Score
# 0    Aarav     Math     85
# 1   Ananya     Math     92
# 2    Rohan     Math     78
# 3     Diya     Math     89
# 4    Aarav  Science     88
# 5   Ananya  Science     95
# 6    Rohan  Science     80
# 7     Diya  Science     90
# 8    Aarav  English     90
# 9   Ananya  English     94
# 10   Rohan  English     79
# 11    Diya  English     88

# %%
# Pivoting the melted DataFrame back to wide format
unmelted_df = melted_df.pivot(index='Name', columns='Subject', values='Score').reset_index()

print("\nUnmelted DataFrame:")
unmelted_df
# Out:
# Unmelted DataFrame:
# Subject    Name  English  Math  Science
# 0         Aarav       90    85       88
# 1        Ananya       94    92       95
# 2          Diya       88    89       90
# 3         Rohan       79    78       80

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# ## Table of Content
# 1. **[Reshape](#Reshape)**
# 2. **[Pivoting](#Pivoting)**
# 3. **[Duplicating](#Duplicating)**
# 4. **[Replacing](#Replacing)**
# 5. **[Indexing](#Indexing)**
# 6. **[Summary Statistics](#Summary_Statistics)**
# 7. **[Merge, Join, Concatenate](#merge)**

# %% [markdown]
# <a id='Reshape'></a>
# ## 1. Reshape

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Write a program to reshape the given data frame using the melt function
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Day</th>
# <th>ICIC</th>
# <th>HDFC</th>
# </tr>
# <tr>
# <td>MON</td>
# <td>1129</td>
# <td>191</td>
# </tr>
# <tr>
# <td>TUES</td>
# <td>1132</td>
# <td>192</td>
# </tr>
# <tr>
# <td>WED</td>
# <td>1134</td>
# <td>190</td>
# </tr>
# <tr>
# <td>THU</td>
# <td>1152</td>
# <td>190</td>
# </tr>
# <tr>
# <td>FRI</td>
# <td>1152</td>
# <td>188</td>
# </tr>
#
# </table>

# %%
# Write your code here
import pandas as pd

df = pd.DataFrame({'Day': ['MON', 'TUEs', 'WED', 'THU', 'FRI'], 'ICICI':[1129, 1132, 1134, 1152, 1152],
                   'HDFC': [191, 192, 190, 190, 188]})

df.reset_index()

# %%
df

# %%
df.set_index('Day')

# %%
df_melt = df.melt(id_vars=['Day'],
    value_vars=['ICICI'])

# %%
df_melt

# %%
df_melt_1 = df.melt(id_vars=['Day'],
    value_vars=['ICICI', 'HDFC'])

# %%
df_melt_1

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Stack the data frame at level 1
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# header = pd.MultiIndex.from_product([['First_Semester','Second_Semester'],['Machine Learning','Python']])
#
# data=([[12,45,67,56],[78,89,45,67],[45,67,89,90],[67,44,56,55]])
#
# df_student = pd.DataFrame(data,
#                   index=['John','Bobby','Cathrine','Jack'],
#                   columns=header)
# df_student

# %%
header = pd.MultiIndex.from_product([['First_Semester','Second_Semester'],['Machine Learning','Python']])

data=([[12,45,67,56],[78,89,45,67],[45,67,89,90],[67,44,56,55]])

df_student = pd.DataFrame(data, index=['John','Bobby','Cathrine','Jack'], columns=header) 
df_student

# %%
# Write your code here
df_student.stack(0)

# %%
df_student.stack(1)

# %% [markdown]
# <a id='Pivoting'></a>
# ## 2. Pivoting

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3. Find the average sales for each store
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# Write your code here

# %%
dataframe_3 = pd.DataFrame({'Store':['A', 'B', 'A', 'C', 'D', 'A', 'D', 'A', 'C', 'B'], 
                          'Location':['Mumbai', 'Pune', 'Hyderabad', 'Mumbai', 'Pune', 'Delhi', 'Hyderabad', 'Pune', 'Mumbai', 'Pune'],
                         'Sales':[40000, 45000, 50000, 90000, 89000, 87000,85000, 78000, 89000, 70000]})

# %%
dataframe_3

# %%
df_gp = dataframe_3.groupby('Store')

# %%
df_gp.describe()

# %%
df_gp.mean()

# %%
dataframe_3.groupby('Store')['Sales'].mean()

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Use Sales, Store and Location from the given data frame and compute 'Mean Sales' for each store by location.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# Write your code here
dataframe_4 = pd.DataFrame({'Store':['A', 'B', 'A', 'C', 'D', 'A', 'D', 'A', 'C', 'B'], 
                          'Location':['Mumbai', 'Pune', 'Hyderabad', 'Mumbai', 'Pune', 'Delhi', 'Hyderabad', 'Pune', 'Mumbai', 'Pune'],
                         'Sales':[40000, 45000, 50000, 90000, 89000, 87000,85000, 78000, 89000, 70000]})
dataframe_4

# %%
df_gp_loc = dataframe_4.groupby('Location')
df_gp_loc.mean()

# %%
dataframe_4.groupby('Location')['Sales'].mean()

# %%
dataframe_4.groupby('Location').mean()

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Compute “minimum” sales for each store by location
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# Write your code here
dataframe_4.groupby('Store').min()

# %% [markdown]
# <a id='Duplicating'></a>
# ## 3. Duplicating

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Find duplicate rows based on all columns
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
# Write your code here

emp_sal_city = [('John', 3400, 'Sydeny'), 
              ('Robert', 3000, 'Chicago'), 
              ('Aadi', 1600, 'New York'),
              ('Robert', 3000,'Chicago'),
              ('Robert', 3000,'Chicago'),
              ('Robert', 3000, 'Texas'),
              ('Aadi', 4000, 'London'),
              ('Sachine', 3000, 'Chicago')
             ]

dataframe_6 = pd.DataFrame(emp_sal_city, columns = ['Name', 'Salary', 'City'])
dataframe_6.set_index('Name', inplace=False)
duplicate_rows = dataframe_6[dataframe_6.duplicated()]
print(duplicate_rows)

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Select duplicate rows based on all columns except the last occurrence of the duplicate.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
# Write your code here
dataframe_7 = pd.DataFrame({'Name':['John', 'Robert', 'Aadi', 'Robert', 'Robert', 'Robert', 'Aadi', 'Sachine'],
                           'Salary':[3400, 3000, 1600, 3000, 3000, 3000, 4000, 3000],
                            'City': ['Sydeny', 'Chicago', 'New York', 'Chicago', 'Chicago', 'Texas', 'London', 'Chicago']
                           })

# %%
duplicate_rows = dataframe_6[dataframe_6.duplicated(keep = 'last')]
print(duplicate_rows)

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8. Find & select duplicated rows based on a two column names (salary and city)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
# write your code here
duplicate_rows = dataframe_6[dataframe_6.duplicated(subset=['Salary', 'City'])]
duplicate_rows

# %% [markdown]
# <a id='Replacing'></a>
# ## 4. Replacing

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9.  Replace 'football' in the column tournament with 'hockey'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
# Write your code

day_tnrt = ({'Days': ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri'],
             'Tournament': ['Football','Cricket', 'Football', 'Football', 'Cricket']})

dataframe_9 = pd.DataFrame(day_tnrt, columns= ['Days', 'Tournament'])
dataframe_9.set_index('Days')

dataframe_9.replace('Football', 'Hockey')

# %%
dataframe_9.replace({'Tournament': {'Football': 'Hockey'}})

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10.  Replace all 0 in column gender with male and 1 with female
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Num_Children</th>
# <th>Gender</th>
# </tr>
# <tr>
# <td>John</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>4</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Johny</td>
# <td>5</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>3</td>
# <td>1</td>
# </tr>
#
# </table>

# %%
# Write your code her

name_child_gen = ({'Name': ['John', 'Robert', 'Johny', 'Mia'],
                   'Num_children': [0,4,5,3],
                   'Gender': [0, 0, 0, 1]})

dataframe_10 = pd.DataFrame(name_child_gen)
print(dataframe_10)
dataframe_10.replace({'Gender': {0:'male', 1:'female'}})

# %% [markdown]
# <a id='Indexing'></a>
# ## 5. Indexing

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 11.  Get the 'Name' and 'City' columns as an index from the below data frame
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>City</th>
# <th>Sales</th>
# <th>Expenses</th>
# </tr>
# <tr>
# <td>John</td>
# <td>New York</td>
# <td>50000</td>
# <td>42000</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>Chicago</td>
# <td>52000</td>
# <td>43000</td>
# </tr>
# <tr>
# <td>Jony</td>
# <td>Texas</td>
# <td>90000</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>California</td>
# <td>34000</td>
# <td>44000</td>
# </tr>
# <tr>
# <td>Edward</td>
# <td>Sydney</td>
# <td>42000</td>
# <td>38000</td>
# </tr>
# <tr>
# <td>Thomas</td>
# <td>New York</td>
# <td>72000</td>
# <td>39000</td>
# </tr>
# <tr>
# <td>Ethan</td>
# <td>Chicago</td>
# <td>49000</td>
# <td>42000</td>
# </tr>
# <tr>
# <td>Olivia</td>
# <td>Sydeney</td>
# <td>55000</td>
# <td>60000</td>
# </tr>
# <tr>
# <td>Arun</td>
# <td>California</td>
# <td>67000</td>
# <td>39000</td>
# </tr>
# <tr>
# <td>Ankita</td>
# <td>Texas</td>
# <td>65000</td>
# <td>44000</td>
# </tr>
# <tr>
# <td>Paulo</td>
# <td>Chicago</td>
# <td>67000</td>
# <td>45000</td>
# </tr>
#
# </table>

# %%
# Write your code here
employees = ({'Name':['John', 'Robert', 'Jony', 'Mia', 'Edward', 'Thomas', 'Ethan', 'Olivia', 'Arun', 'Ankita', 'Paulo'],
              'City': ['New York', 'Chicago', 'Texas', 'California', 'Sydney', 'New York', 'Chicago', 'Sydney', 'California', 'Texas', 'Chicago'],
              'Sales': [50000, 52000, 90000, 34000, 42000, 72000, 49000, 55000, 67000, 65000, 67000],
              'Expenses': [42000, 43000, 50000, 44000, 38000, 39000, 42000, 60000, 39000, 44000, 45000]})

dataframe_11 = pd.DataFrame(employees, )
dataframe_11.set_index(['Name', 'City'])
dataframe_11.loc[:,['Name','City']]

# %%
dataframe_11.filter(['Name', 'City'])

# %%
dataframe_11[['Name','City']]

# %% [markdown]
# <a id='Summary_Statistics'></a>
# ## 6. Summary Statistics

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 12.  Get the descriptive statistics for the sales column from the given data frame
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
# Write your code here
mon_sales_seasons = ({'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                      'Sales': [22000, 27000, 25000, 29000, 35000, 67000, 78000, 67000, 56000, 56000, 56000, 60000],
                      'Seasons': ['Winter', 'Winter', 'Spring', 'Spring', 'Spring', 'Summer', 'Summer', 'Summer', 'Fall', 'Fall', 'Fall', 'Winter']
                     })

# %%
dataframe_12 = pd.DataFrame(mon_sales_seasons, columns = ['Month', 'Sales', 'Seasons'])
dataframe_12['Sales'].describe()

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 13.  Save median of sales for each season in the data frame
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
# Write your code here
mon_sales_seasons = ({'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                      'Sales': [22000, 27000, 25000, 29000, 35000, 67000, 78000, 67000, 56000, 56000, 56000, 60000],
                      'Seasons': ['Winter', 'Winter', 'Spring', 'Spring', 'Spring', 'Summer', 'Summer', 'Summer', 'Fall', 'Fall', 'Fall', 'Winter']
                     })
dataframe_13 = pd.DataFrame(mon_sales_seasons, columns = ['Month', 'Sales', 'Seasons'])
a = dataframe_13.groupby(['Seasons']).median()
print(dataframe_13.groupby(['Seasons']).median('Sales'))
a

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 14. Store descriptive statistics for categorical data to a data frame
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
# Write your code here
mon_sales_seasons = ({'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                      'Sales': [22000, 27000, 25000, 29000, 35000, 67000, 78000, 67000, 56000, 56000, 56000, 60000],
                      'Seasons': ['Winter', 'Winter', 'Spring', 'Spring', 'Spring', 'Summer', 'Summer', 'Summer', 'Fall', 'Fall', 'Fall', 'Winter']
                     })
dataframe_14 = pd.DataFrame(mon_sales_seasons, columns = ['Month', 'Sales', 'Seasons'])

dataframe_14.describe(include = 'all')

# %%
dataframe_14 = pd.DataFrame({'categorical': pd.Categorical(['Month', 'Seasons'])})
print(dataframe_14.describe())

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 15. Find the kurtosis for each subject
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
# Write your code here
students = ({'Name': ['Emma', 'Mia', 'Sophia', 'James', 'John'],
             'Maths': [56, 78, 78, 67, 88],
             'Science': [89, 87, 78, 89, 78],
             'English': [89, 89, 76, 78, 87]
            })

dataframe_15 = pd.DataFrame(students)
print(dataframe_15)
dataframe_15.kurtosis(axis=0)

# %%
dataframe_15.kurtosis()

# %% [markdown]
# <a id='merge'></a>
# ## 7. Merge, Join, Concatenate

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 16. Merge the given data frames by 'ID' column
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
# Write your code here

data1 = ({'ID': [101, 102, 103, 104, 105],
          'Name': ['Alex', 'Amy', 'Alen', 'Alice', 'Ayoung'],
          'Subject': ['Maths', 'English', 'Science', 'German', 'History']})

data2 = ({'ID': [101, 102, 103, 104, 105],
          'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
          'Subject': ['English', 'Science', 'Social Science', 'German', 'History']})

dataframe_16a = pd.DataFrame(data1)
dataframe_16b = pd.DataFrame(data2)

print(dataframe_16a)
print('\n')
print(dataframe_16b)
print('\n')
print(dataframe_16a.merge(dataframe_16b, on='ID'))
dataframe_16a.merge(dataframe_16b, how='inner', on='ID')

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 17. Merge the given data frames by 'ID' and 'Subject'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
# Write your code here

print(dataframe_16a.merge(dataframe_16b, on=['ID', 'Subject']))
dataframe_16a.merge(dataframe_16b, how='inner', on=['ID', 'Subject'])

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 18. Perform left merge to only combine values in the column 'Subject' that match
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
# Write your here

dataframe_16a.merge(dataframe_16b, how='left', on=['Subject'])

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 19. Perform outer merge to combine values, only if the column 'Subject' match
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
# Write your code here
dataframe_16a.merge(dataframe_16b, how='outer', on=['Subject'])

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="../images/RA_Logo.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 20. Concatenate rows of two data frames and assign keys
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the data frame given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
# Write your code here

data1 = ({'ID': [101, 102, 103, 104, 105],
          'Name': ['Alex', 'Amy', 'Alen', 'Alice', 'Ayoung'],
          'Subject': ['Maths', 'English', 'Science', 'German', 'History']})

data2 = ({'ID': [101, 102, 103, 104, 105],
          'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
          'Subject': ['English', 'Science', 'Social Science', 'German', 'History']})

# %%
dataframe_20a = pd.DataFrame(data1)
dataframe_20b = pd.DataFrame(data2)

# %%
frames = {'x': dataframe_20a, 'y': dataframe_20b}

# %%
result = pd.concat(frames)
result

# %%
result = pd.concat(frames, keys = ['x', 'y'], axis = 0)

# %%
result

# %%
result.loc['y']

# %%
result.loc['x']

# %%
import os
os.getcwd()
# Out:
# '/Users/vidyadharbendre/workspace/advanced_python/learn_advanced_python_using_examples/notebooks/Advanced'

# %%
#https://www.kaggle.com/datasets/ruiromanini/mtcars?select=mtcars.csv

# %%
df = pd.read_csv('../../data/mtcars.csv')
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df.shape
# Out:
# (32, 12)
